# %%
import os
import glob as glob
import matplotlib.pyplot as plt
import cv2
import requests
import random
import numpy as np

np.random.seed(42)

# %%
TRAIN = True
# Number of epochs to train for.
EPOCHS = 75

# %% [markdown]
# The dataset is structured in the following manner:
#
# ```
# ├── data.yaml
# ├── README.dataset.txt
# ├── README.roboflow.txt
# ├── test
# │   ├── images
# │   └── labels
# ├── train
# │   ├── images
# │   └── labels
# └── valid
#     ├── images
#     └── labels
#
# ```

# %%
class_names = ['employee_tag']
colors = np.random.uniform(0, 255, size=(len(class_names), 3))

# %%
# Function to convert bounding boxes in YOLO format to xmin, ymin, xmax, ymax.
def yolo2bbox(bboxes):
    xmin, ymin = bboxes[0]-bboxes[2]/2, bboxes[1]-bboxes[3]/2
    xmax, ymax = bboxes[0]+bboxes[2]/2, bboxes[1]+bboxes[3]/2
    return xmin, ymin, xmax, ymax

# %%
def plot_box(image, bboxes, labels):
    # Need the image height and width to denormalize
    # the bounding box coordinates
    h, w, _ = image.shape
    for box_num, box in enumerate(bboxes):
        x1, y1, x2, y2 = yolo2bbox(box)
        # denormalize the coordinates
        xmin = int(x1*w)
        ymin = int(y1*h)
        xmax = int(x2*w)
        ymax = int(y2*h)
        width = xmax - xmin
        height = ymax - ymin
        
        class_name = class_names[int(labels[box_num])]
        
        cv2.rectangle(
            image, 
            (xmin, ymin), (xmax, ymax),
            color=colors[class_names.index(class_name)],
            thickness=2
        ) 

        font_scale = min(1,max(3,int(w/500)))
        font_thickness = min(2, max(10,int(w/50)))
        
        p1, p2 = (int(xmin), int(ymin)), (int(xmax), int(ymax))
        # Text width and height
        tw, th = cv2.getTextSize(
            class_name, 
            0, fontScale=font_scale, thickness=font_thickness
        )[0]
        p2 = p1[0] + tw, p1[1] + -th - 10
        cv2.rectangle(
            image, 
            p1, p2,
            color=colors[class_names.index(class_name)],
            thickness=-1,
        )
        cv2.putText(
            image, 
            class_name,
            (xmin+1, ymin-10),
            cv2.FONT_HERSHEY_SIMPLEX,
            font_scale,
            (255, 255, 255),
            font_thickness
        )
    return image

# %%
# Function to plot images with the bounding boxes.
def plot(image_paths, label_paths, num_samples):
    all_training_images = glob.glob(image_paths)
    all_training_labels = glob.glob(label_paths)
    all_training_images.sort()
    all_training_labels.sort()
    
    num_images = len(all_training_images)
    
    plt.figure(figsize=(15, 12))
    for i in range(num_samples):
        j = random.randint(0,num_images-1)
        image = cv2.imread(all_training_images[j])
        with open(all_training_labels[j], 'r') as f:
            bboxes = []
            labels = []
            label_lines = f.readlines()
            for label_line in label_lines:
                label = label_line[0]
                bbox_string = label_line[2:]
                x_c, y_c, w, h = bbox_string.split(' ')
                x_c = float(x_c)
                y_c = float(y_c)
                w = float(w)
                h = float(h)
                bboxes.append([x_c, y_c, w, h])
                labels.append(label)
        result_image = plot_box(image, bboxes, labels)
        plt.subplot(2, 2, i+1)
        plt.imshow(result_image[:, :, ::-1])
        plt.axis('off')
    plt.subplots_adjust(wspace=0)
    plt.tight_layout()
    plt.show()

# %%
# Visualize a few training images.
plot(
    image_paths='train/images/*', 
    label_paths='train/labels/*',
    num_samples=4,
)

# %% [markdown]
# ## Helper Functions for Logging
#
# Here, we write the helper functions that we need for logging of the results in the notebook while training the models.
#
# Let's create our custom result directories so that we can easily keep track of them and carry out inference using the proper model.

# %%
def set_res_dir():
    # Directory to store results
    res_dir_count = len(glob.glob('runs/train/*'))
    print(f"Current number of result directories: {res_dir_count}")
    if TRAIN:
        RES_DIR = f"results_{res_dir_count+1}"
        print(RES_DIR)
    else:
        RES_DIR = f"results_{res_dir_count}"
    return RES_DIR

# %% [markdown]
# **Function to Monitor TensorBoard logs**.

# %%
def monitor_tensorboard():
    # %load_ext tensorboard
    # %tensorboard --logdir runs/train

# %% [markdown]
# ## Clone YOLOV5 Repository

# %%
if not os.path.exists('yolov5'):
    # !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5/
# !cd
# Out:
# C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\yolov5
# C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (3.1.42)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.8.3)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: Pillow>=9.4.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (10.2.0)
# Requirement already satisfied: psutil in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (1.11.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (0.17.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 17)) (4.65.0)
# Requirement already satisfied: ultralytics>=8.0.232 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 18)) (8.1.19)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\yewyn\anaconda3\lib\site-packages (from -r requirements.txt (line 42)) (68.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\yewyn\anaconda3\lib\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yewyn\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yewyn\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yewyn\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yewyn\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yewyn\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.10.0)
# Requirement already satisfied: sympy in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\yewyn\anaconda3\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\yewyn\anaconda3\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\yewyn\anaconda3\lib\site-packages (from ultralytics>=8.0.232->-r requirements.txt (line 18)) (8.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yewyn\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\yewyn\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\yewyn\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\yewyn\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yewyn\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\yewyn\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)

# %%
monitor_tensorboard()
# Out:
# Reusing TensorBoard on port 6006 (pid 1064), started 4:18:57 ago. (Use '!kill 1064' to kill it.)
#       <iframe id="tensorboard-frame-acbbb63a242b96ee" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-acbbb63a242b96ee");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from yolov5.train import run

run(data='../data.yaml' , weights='yolov5s.pt', img=640, epochs=EPOCHS, batch_size=16 , name=set_res_dir())
# Out:
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=../data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=75, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=results_6, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False, img=640
# Current number of result directories: 5
# results_6
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-287-g574331f9 Python-3.11.5 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\train\labels... 5582 images, 4880 backgrounds, 0 corrupt: 100%|██████████| 5582/5582 [00:10<00:00, 519.91it/s]
# train: WARNING  Cache directory C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\train is not writeable: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\yewyn\\Documents\\footfall_task\\training_data_roboflow\\train\\labels.cache.npy' -> 'C:\\Users\\yewyn\\Documents\\footfall_task\\training_data_roboflow\\train\\labels.cache'
# val: Scanning C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\valid\labels... 669 images, 594 backgrounds, 0 corrupt: 100%|██████████| 669/669 [00:08<00:00, 76.29it/s]
# val: WARNING  Cache directory C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\valid is not writeable: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\yewyn\\Documents\\footfall_task\\training_data_roboflow\\valid\\labels.cache.npy' -> 'C:\\Users\\yewyn\\Documents\\footfall_task\\training_data_roboflow\\valid\\labels.cache'
#
# AutoAnchor: 3.20 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\results_6\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\train\results_6
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/74       3.5G    0.05339   0.006014          0          2        640: 100%|██████████| 349/349 [00:54<00:00,  6.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  5.40it/s]
#                    all        669         75          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/74       4.7G    0.03352   0.002075          0          0        640: 100%|██████████| 349/349 [00:44<00:00,  7.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.44it/s]
#                    all        669         75    0.00073     0.0267   0.000388   7.69e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/74       4.7G    0.03005   0.001786          0          1        640: 100%|██████████| 349/349 [00:49<00:00,  7.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  5.88it/s]
#                    all        669         75    0.00177      0.293    0.00277   0.000439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/74       4.7G    0.02849   0.001539          0          2        640: 100%|██████████| 349/349 [00:47<00:00,  7.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  5.65it/s]
#                    all        669         75   0.000361       0.16    0.00115   0.000171
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/74       4.7G    0.02461   0.001695          0          4        640: 100%|██████████| 349/349 [00:49<00:00,  7.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  5.95it/s]
#                    all        669         75    0.00132      0.493    0.00211   0.000391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/74       4.7G    0.02414   0.001605          0          0        640: 100%|██████████| 349/349 [00:45<00:00,  7.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.23it/s]
#                    all        669         75    0.00213      0.707     0.0187     0.0047
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/74       4.7G    0.02191   0.001655          0          4        640: 100%|██████████| 349/349 [00:44<00:00,  7.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.15it/s]
#                    all        669         75    0.00181       0.36    0.00124    0.00046
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/74       4.7G    0.02186   0.001597          0          0        640: 100%|██████████| 349/349 [00:46<00:00,  7.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.01it/s]
#                    all        669         75      0.018      0.907     0.0361     0.0128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/74       4.7G    0.01983   0.001676          0          0        640: 100%|██████████| 349/349 [00:45<00:00,  7.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.16it/s]
#                    all        669         75    0.00255      0.947     0.0245     0.0062
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/74       4.7G    0.01994   0.001598          0          1        640: 100%|██████████| 349/349 [00:46<00:00,  7.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.07it/s]
#                    all        669         75    0.00859       0.96      0.197     0.0982
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10
20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.29it/s]
#                    all        669         75      0.663      0.987        0.8      0.505
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/74       4.7G   0.009183  0.0007442          0          5        640: 100%|██████████| 349/349 [00:43<00:00,  8.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.04it/s]
#                    all        669         75      0.679      0.987      0.809      0.517
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/74       4.7G   0.009314  0.0007145          0          1        640: 100%|██████████| 349/349 [00:44<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.28it/s]
#                    all        669         75      0.678      0.973      0.806      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/74       4.7G   0.008975  0.0007215          0          2        640: 100%|██████████| 349/349 [00:43<00:00,  8.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.26it/s]
#                    all        669         75      0.679      0.987      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/74       4.7G   0.008844  0.0007273          0          0        640: 100%|██████████| 349/349 [00:42<00:00,  8.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  6.31it/s]
#                    all        669         75      0.689      0.987      0.819       0.53
#
# 75 epochs completed in 1.028 hours.
# Optimizer stripped from runs\train\results_6\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\results_6\weights\best.pt, 14.4MB
#
# Validating runs\train\results_6\weights\best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 21/21 [00:03<00:00,  5.85it/s]
#                    all        669         75      0.488      0.987      0.879       0.54
# Results saved to runs\train\results_6
# Namespace(weights='yolov5s.pt', cfg='', data='../data.yaml', hyp={'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}, epochs=75, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=WindowsPath('data/hyps'), resume_evolve=None, bucket='', cache=None, image_weights=False, device='', multi_scale=False, single_cls=False, optimizer='SGD', sync_bn=False, workers=8, project='runs\\train', name='results_6', exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias='latest', ndjson_console=False, ndjson_file=False, img=640, save_dir='runs\\train\\results_6')

# %%
RES_DIR = 'results_6'

# %%
import os
import pathlib


# Function to show validation predictions saved during training.
def show_valid_results(RES_DIR):
    print(RES_DIR)
    EXP_PATH = f"runs\\train\\{RES_DIR}"
    validation_pred_images = glob.glob(f"{EXP_PATH}\\*_pred.jpg")
    print(validation_pred_images)
    for pred_image in validation_pred_images:
        #pred_image = pathlib.Path(pred_image).resolve()
        image = cv2.imread(pred_image)
        plt.figure(figsize=(19, 16))
        plt.imshow(image[:, :, ::-1])
        plt.axis('off')
        plt.savefig(f"{EXP_PATH}\\pred_image.jpg")

# %%
from detect import run
# Helper function for inference on images.
def inference(RES_DIR, data_path):
    # Directory to store inference results.
    infer_dir_count = len(glob.glob('runs\\detect\\*'))
    print(f"Current number of inference detection directories: {infer_dir_count}")
    INFER_DIR = f"inference_{infer_dir_count+1}"
    print(INFER_DIR)
    # Inference on images.
    run(weights = f"runs\\train\\{RES_DIR}\\weights\\best.pt", source = data_path, name = INFER_DIR, save_txt = True)
    return INFER_DIR

# %%
def visualize(INFER_DIR):
# Visualize inference images.
    INFER_PATH = f"runs\\detect\\{INFER_DIR}"
    infer_images = glob.glob(f"{INFER_PATH}\\*.jpg")
    print(infer_images)
    for pred_image in infer_images:
        image = cv2.imread(pred_image)
        plt.figure(figsize=(19, 16))
        plt.imshow(image[:, :, ::-1])
        plt.axis('off')
        plt.show()

# %%
# %cd yolov5
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5'
# C:\Users\yewyn\Documents\footfall_task\training_data_roboflow\yolov5

# %%
show_valid_results(RES_DIR)
# Out:
# results_6
# ['runs\\train\\results_6\\val_batch0_pred.jpg', 'runs\\train\\results_6\\val_batch1_pred.jpg', 'runs\\train\\results_6\\val_batch2_pred.jpg']

# %%
IMAGE_INFER_DIR = inference(RES_DIR, '..\\inferenceImages')
# Out:
# YOLOv5  v7.0-287-g574331f9 Python-3.11.5 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# Fusing layers...
